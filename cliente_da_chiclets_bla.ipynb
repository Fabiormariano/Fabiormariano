# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabiormariano/Fabiormariano/blob/main/cliente_da_chiclets_bla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
encodings = ['utf-8', 'latin-1', 'ISO-8859-1']

# %%
df = pd.read_csv("telecom_users.csv")

# %%
display(df)
# Out:
#       Unnamed: 0   IDCliente     Genero  Aposentado Casado Dependentes  \
# 0           1869  7010-BRBUU  Masculino           0    Sim         Sim
# ...          ...         ...        ...         ...    ...         ...
# 5985         860  4795-UXVCJ  Masculino           0    Nao         Nao
#
#       MesesComoCliente ServicoTelefone MultiplasLinhas ServicoInternet  ...  \
# 0                   72             Sim             Sim             Nao  ...
# ...                ...             ...             ...             ...  ...
# 5985                26             Sim             Nao             Nao  ...
#
#      ServicoSuporteTecnico ServicoStreamingTV ServicoFilmes TipoContrato  \
# 0              SemInternet        SemInternet   SemInternet       2 anos
# ...                    ...                ...           ...          ...
# 5985           SemInternet        SemInternet   SemInternet        Anual
#
#      FaturaDigital FormaPagamento ValorMensal TotalGasto Churn  Codigo
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('cliente.csv', encoding='iso-8859-1', delimiter=';')

# %%
display(df)
# Out:
#                        Nome     Empresa     Cidade Estado  \
# 0     Marcio Ferreira Cravo   H F Cravo  Cabo Frio     RJ
# ...                     ...         ...        ...    ...
# 2177    Mirian Fenoll Ramal  Telestereo   Brasilia     DF
#
#                   Endereço  Nro Complemento  Bairro        Cep    Pais
# 0     R Bento Jose Ribeiro    1         NaN  Centro  28905-090  Brasil
# ...                    ...  ...         ...     ...        ...     ...
# 2177        Sclrn 705 Bl D  NaN     Loja 51     NaN  70000-000  Brasil
#
# [2178 rows x 10 columns]

# %%
pd.set_option('display.max_rows', 100)

# %%
display(df)
# Out:
#                                Nome      Empresa                Cidade Estado  \
# 0             Marcio Ferreira Cravo    H F Cravo             Cabo Frio     RJ
# 1             Samantha Vieira Gomes    H F Cravo             Cabo Frio     RJ
# 2                Jackson Ken Yamaga          Kl2            Ananindeua     PA
# 3     Vangevaldo Batista Santa'Anna    Convidado             Sao Paulo     SP
# 4                Jose Ribeiro Alves  Construjota  Planaltina De GoiÃ¡s     GO
# ...                             ...          ...                   ...    ...
# 2173     Enor Rodrigues De Oliveira    Rock Mate                   NaN    NaN
# 2174          Ana Paula De Carvalho    Sebrae DF             BrasÃ­lia     DF
# 2175              Diego Dytz Abrego        Skafe            Lago Norte     DF
# 2176                Diana Rodriguez          NaN        Aguascalientes    NaN
# 2177            Mirian Fenoll Ramal   Telestereo              Brasilia     DF
#
# ...

# %%
procurar_nome = ''

# %%
# prompt: TESTE

# This code does not depend on any preceding code, so it can be executed independently.
print("TESTE")

# %% [markdown]
# # Nova seção

# %%
empresa_procurada = "H F Cravo"

# %%
#resultados = df.loc[df['Nome'] == procurar_nome]

# %%
resultados = df.loc[(df['Nome'] == procurar_nome ) | (df['Empresa'] == empresa_procurada)]

# %%
print(resultados)
# Out:
#                     Nome    Empresa     Cidade Estado              Endereço  \
# 0  Marcio Ferreira Cravo  H F Cravo  Cabo Frio     RJ  R Bento Jose Ribeiro
# 1  Samantha Vieira Gomes  H F Cravo  Cabo Frio     RJ  R Bento Jose Ribeiro
#
#   Nro Complemento  Bairro        Cep    Pais
# 0   1         NaN  Centro  28905-090  Brasil
# 1   1         NaN  Centro  28905-090  Brasil
