# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabiormariano/Fabiormariano/blob/main/trabalho_tcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GANHOS COM SERVIÇOS
#
# ---
#
#
# ---

# %%
import matplotlib.pyplot as plt

meses = ['Mês 1', 'Mês 2', 'Mês 3', 'Mês 4', 'Mês 5', 'Mês 6', 'Mês 7', 'Mês 8', 'Mês 9', 'Mês 10', 'Mês 11', 'Mês 12']
vendas_totais = [745039.20, 1245045.50, 1872049.00, 2185070.00, 2278070.00, 2347570.00, 1726035.00, 1496038.50, 1500535.00, 2650575.00, 3167080.00, 3426085.00]

plt.figure(figsize=(10, 6))
plt.plot(meses, vendas_totais, marker='o', linestyle='-', color='b')
plt.title('Vendas Totais Mensais - Ano 01')
plt.xlabel('Meses')
plt.ylabel('Vendas (R$)')
plt.grid(True)
plt.show()

# %%
vendas_locacao = [560000, 975000, 1400000, 1540000, 1610000, 1610000, 1000000, 825000, 900000, 1950000, 2400000, 2550000]

plt.figure(figsize=(10, 6))
plt.plot(meses, vendas_locacao, marker='o', linestyle='-', color='g')
plt.title('Vendas de Locação de Imóveis Mensais')
plt.xlabel('Meses')
plt.ylabel('Vendas (R$)')
plt.grid(True)
plt.show()

# %%
vendas_servicos = [57000, 90000, 180000, 270000, 288000, 315000, 270000, 252000, 208000, 240000, 272000, 324000]

plt.figure(figsize=(10, 6))
plt.plot(meses, vendas_servicos, marker='o', linestyle='-', color='r')
plt.title('Vendas de Prestação de Serviços Mensais')
plt.xlabel('Meses')
plt.ylabel('Vendas (R$)')
plt.grid(True)
plt.show()

# %% [markdown]
# CALCULOS CUSTOS TOTAIS

# %%
import matplotlib.pyplot as plt

meses = ['Mês 1', 'Mês 2', 'Mês 3', 'Mês 4', 'Mês 5', 'Mês 6', 'Mês 7', 'Mês 8', 'Mês 9', 'Mês 10', 'Mês 11', 'Mês 12']
custo_locacao = [750000, 1125000, 1500000, 1650000, 1725000, 1725000, 1500000, 1125000, 1350000, 1950000, 2250000, 2250000]
custo_servicos = [57000, 90000, 150000, 225000, 240000, 262500, 225000, 210000, 195000, 225000, 255000, 270000]
custo_limpeza = [8.40, 8.40, 8.40, 12.00, 12.00, 12.00, 8.40, 8.40, 8.40, 12.00, 12.00, 12.00]
custo_hospedagem = [42.00, 56.00, 105.00, 105.00, 112.00, 115.50, 126.00, 119.00, 108.50, 108.50, 119.00, 140.00]
custo_estacionamento = [80000, 120000, 160000, 150000, 140000, 142000, 150000, 130000, 160000, 190000, 200000, 210000]
custo_publicidade = [500, 200, 300, 350, 500, 500, 550, 500, 500, 700, 700, 700]
custo_assinatura = [750, 1800, 1800, 2100, 2100, 2400, 3000, 3000, 3000, 3900, 4800, 4800]
custo_garantia_cartao = [1200, 480, 480, 560, 560, 640, 800, 800, 800, 1040, 1280, 1280]
custo_transicao_sucesso = [1500, 3000, 3250, 3500, 3800, 4000, 4000, 6000, 4500, 5000, 5000, 5000]

# Plotando os gráficos
plt.figure(figsize=(12, 8))

plt.plot(meses, custo_locacao, label='Locação de Imóveis', marker='o')
plt.plot(meses, custo_servicos, label='Prestação de Serviços', marker='o')
plt.plot(meses, custo_limpeza, label='Serviços de Limpeza', marker='o')
plt.plot(meses, custo_hospedagem, label='Taxa de Hospedagem (%)', marker='o')
plt.plot(meses, custo_estacionamento, label='Taxa de Estacionamento', marker='o')
plt.plot(meses, custo_publicidade, label='Publicidade', marker='o')
plt.plot(meses, custo_assinatura, label='Assinatura Premium Locatorios', marker='o')
plt.plot(meses, custo_garantia_cartao, label='Taxa de Garantia Uso Cartão de Crédito', marker='o')
plt.plot(meses, custo_transicao_sucesso, label='Taxa de Transição Bem Sucedida Locação', marker='o')

plt.title('Custos Totais Mensais por Categoria')
plt.xlabel('Meses')
plt.ylabel('Custos (R$)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# NOSSAS DISPESAS

# %%
import matplotlib.pyplot as plt

# Dados
categorias = ['Despesa Operacional', 'Salários', 'Retirada dos Sócios', 'Comissões de Vendas', 'Investimento em Marketing',
              'Processadoras de Pagamento', 'Despesas com Serviços', 'Aluguel', 'Água', 'Energia Elétrica',
              'Despesas de Depreciação', 'Outras VR']

valores_mensais = [96950.27, 60200, 144, 54, 120, 360000, 4800, 54000, 7200, 9000, 2400, 3600]

# Criando o gráfico de pizza
plt.figure(figsize=(10, 10))
plt.pie(valores_mensais, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribuição Percentual das Despesas ao Longo do Ano')
plt.show()
